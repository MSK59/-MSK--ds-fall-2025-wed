# %% [markdown]
# # First print your name in the cell below then save this file. (or something nice about your instructor)

# %%
# In this cell print your name 
print('Muhammad Saad Khalid')
# Out:
# Muhammad Saad Khalid

# %%
print('I appreciate how helpful the instructors are')
# Out:
# I appreciate how helpful the instructors are

# %% [markdown]
# # Data wrangling with Pandas exercise
# * For this exercise we will be using the `listings.csv` data file.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in the data file using `pd.read_csv()`

# %%
# Load data here
listing_df = pd.read_csv('/workspaces/-MSK--ds-fall-2025-wed/Week-01-Pandas/data/listings.csv')

# %% [markdown]
# ## Exercise 2 - Filtering
#
# Return the following subsets of the dataframe.
#
# 1. How many listings are there with a price less than 100?
#
#
# 2. Find how many listings there are in just Brooklyn.
#
#
# 3. Find how many listings there are in Brooklyn with a price less than 100.
#
#
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
#
#
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  The prices for all other listings should be the same as the were before.
#
#
# 6. What % of the rooms are private, and what % of the rooms are shared.
#     * Hint, use `.value_counts()`

# %%
# 1. How many listings are there with a price less than 100? 
print(len(listing_df[listing_df['price'] < 100]))
# Out:
# 22778

# %%
# 2. Make a new DataFrame of listings in Brooklyn named `df_bk` 
# and find how many listings in just Brooklyn.

df_bk = listing_df[listing_df['neighbourhood_group'] == 'Brooklyn']
print(len(df_bk))
# Out:
# 18632

# %%
# 3. Find how many listings there are in Brooklyn with a price less than 100.

print(len(df_bk[df_bk['price'] < 100]))
# Out:
# 10473

# %%
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
# How many total are there that have those names

print(len(df_bk[df_bk['host_name'].isin(['Michael', 'David', 'John', 'Daniel'])]))
# Out:
# 457

# %%
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  
# The prices for all other listings should be the same as the were before.

df_bk['adjusted_price'] = df_bk.loc[:, 'price'] # Initialize with a default value

df_bk.loc[(df_bk['neighbourhood'] == 'Williamsburg'), 'adjusted_price'] = df_bk.loc[df_bk['neighbourhood'] == 'Williamsburg', 'price'] + 100

df_bk
# Out:
# /tmp/ipykernel_46610/4235370314.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bk['adjusted_price'] = df_bk.loc[:, 'price'] # Initialize with a default value
#              id                                               name    host_id  \
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 8          5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# 11         6848                   Only 2 stops to Manhattan studio      15991
# ...         ...                                                ...        ...
# ...

# %%
# 6. What % of the rooms are private, and what % of the rooms are shared.  
private_percent = len(df_bk[df_bk['room_type'] == 'Private room'])/len(df_bk) * 100
shared_percent = len(df_bk[df_bk['room_type'] == 'Shared room'])/len(df_bk) * 100

print(f'{private_percent:.2f}%')
print(f'{shared_percent:.2f}%')
# Out:
# 49.16%
# 1.78%

# %% [markdown]
# # Exercise 3 - Grouping
#
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
#
#
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups.
#
#
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups.
#
#
# 4. Using `groupby`, find the median price for each room type in each neighbourhood_group.
#
#
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices for each room type in each neighbourhood_group.

# %%
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
print(df_bk.groupby('neighbourhood').size()) # size includes NaN values while count does not
# Out:
# neighbourhood
# Bath Beach                     19
# Bay Ridge                     153
# Bedford-Stuyvesant           3438
# Bensonhurst                    66
# Bergen Beach                   16
# Boerum Hill                   171
# Borough Park                  108
# Brighton Beach                 74
# Brooklyn Heights              152
# Brownsville                    80
# Bushwick                     2225
# Canarsie                      174
# Carroll Gardens               217
# Clinton Hill                  543
# Cobble Hill                    94
# Columbia St                    41
# Coney Island                   15
# Crown Heights                1461
# Cypress Hills                 143
# DUMBO                          37
# Downtown Brooklyn              75
# Dyker Heights                  17
# East Flatbush                 491
# East New York                 232
# Flatbush                      581
# Flatlands                      82
# Fort Greene                   434
# ...

# %%
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups. 
print(df_bk.groupby('neighbourhood')['price'].mean())
# Out:
# neighbourhood
# Bath Beach                    92.789474
# Bay Ridge                     99.516340
# Bedford-Stuyvesant           106.781268
# Bensonhurst                   73.121212
# Bergen Beach                 118.312500
# Boerum Hill                  189.842105
# Borough Park                  67.842593
# Brighton Beach               120.635135
# Brooklyn Heights             201.105263
# Brownsville                  102.475000
# Bushwick                      83.265169
# Canarsie                     103.339080
# Carroll Gardens              174.188940
# Clinton Hill                 175.163904
# Cobble Hill                  191.351064
# Columbia St                  173.463415
# Coney Island                  94.533333
# Crown Heights                112.080082
# Cypress Hills                160.272727
# DUMBO                        189.702703
# Downtown Brooklyn            149.706667
# Dyker Heights                 88.235294
# East Flatbush                 86.539715
# ...

# %%
# 2.5. Using `groupby`, find the mean price for each room_type. 
print(df_bk.groupby('room_type')['price'].mean())
# Out:
# room_type
# Entire home/apt    171.587687
# Hotel room         147.300000
# Private room        71.291189
# Shared room         57.870091
# Name: price, dtype: float64

# %%
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups. 
print(df_bk.groupby('neighbourhood')['price'].agg(['min', 'max']))
# Out:
#                            min    max
# neighbourhood
# Bath Beach                  34    300
# Bay Ridge                   17   1750
# Bedford-Stuyvesant          15   6143
# Bensonhurst                 15    250
# Bergen Beach                62    235
# Boerum Hill                 40   1057
# Borough Park                25    300
# Brighton Beach              30    499
# Brooklyn Heights            50   2000
# Brownsville                 25   1500
# Bushwick                    10   2500
# Canarsie                    18    500
# Carroll Gardens             35    934
# Clinton Hill                22   8000
# Cobble Hill                 28   1500
# Columbia St                 42   1080
# Coney Island                27    190
# Crown Heights               16   4000
# Cypress Hills               20   6429
# DUMBO                       51    350
# Downtown Brooklyn           45    366
# Dyker Heights               36    199
# East Flatbush               17    650
# ...

# %%
# 4. Using `groupby`, find the mean price for each room_type in each neighbourhood_group.
df_bk.groupby(['neighbourhood', 'room_type'])['price'].mean()
# Out:
# neighbourhood    room_type
# Bath Beach       Entire home/apt    126.000000
#                  Private room        55.888889
# Bay Ridge        Entire home/apt    158.187500
#                  Private room        58.025000
#                  Shared room         51.111111
#                                        ...
# Williamsburg     Hotel room          65.000000
#                  Private room        79.090399
#                  Shared room         94.562500
# Windsor Terrace  Entire home/apt    152.168224
#                  Private room        66.605263
# Name: price, Length: 133, dtype: float64

# %%
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices 
# for each room type in each neighbourhood_group.
df_bk.groupby(['neighbourhood', 'room_type'])['price'].agg(['count', 'min', 'max', 'mean', 'median', 'std'])
# Out:
#                                  count  min   max        mean  median  \
# neighbourhood   room_type
# Bath Beach      Entire home/apt     10   85   300  126.000000    99.0
#                 Private room         9   34    99   55.888889    52.0
# Bay Ridge       Entire home/apt     64   45  1750  158.187500   105.5
#                 Private room        80   23   164   58.025000    55.0
#                 Shared room          9   17   225   51.111111    28.0
# ...                                ...  ...   ...         ...     ...
# Williamsburg    Hotel room           3    0   195   65.000000     0.0
#                 Private room      1781   19  1300   79.090399    70.0
#                 Shared room         32   21   300   94.562500    71.5
# Windsor Terrace Entire home/apt    107   38   995  152.168224   125.0
#                 Private room        38   30   158   66.605263    61.0
#
#                                         std
# neighbourhood   room_type
# ...

# %% [markdown]
# # Load, Merge, and Export files.
# 1. Load the `prices.csv` and the `n_listings.csv`
#     * Having an error..? Inspect the actual csv file if you're having trouble
#
# 2. Do join that keeps all the records for each table.
#     * Neighbourhood groups should include ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        'LongIsland']
#
#
# 3. Save your joined csv as `joined.csv` into the data folder.
#
#
# 4. Load your saved table and see if it looks the same or different that the DataFrame you used to create it.

# %%
# 1. Load the `prices.csv` and the `n_listings.csv`
prices = pd.read_csv('/workspaces/-MSK--ds-fall-2025-wed/Week-01-Pandas/data/prices.csv')
n_listings = pd.read_csv('/workspaces/-MSK--ds-fall-2025-wed/Week-01-Pandas/data/n_listings.csv')

n_listings[['neighbourhood_group', 'n_listings']] = n_listings['neighbourhood_group;n_listings'].str.split(';', expand = True)
n_listings.drop('neighbourhood_group;n_listings', axis = 1, inplace = True)
n_listings.head()
# Out:
#   neighbourhood_group n_listings
# 0               Bronx       1183
# 1            Brooklyn      18632
# 2           Manhattan      20580
# 3          LongIsland       4121

# %%
# 2. Do join that keeps all the records for each table.
joined_df = pd.merge(prices, n_listings, on = 'neighbourhood_group', how = 'inner')
joined_df.head()
# Out:
#   neighbourhood_group   mean_price n_listings
# 0               Bronx    92.751479       1183
# 1            Brooklyn   120.225258      18632
# 2           Manhattan   191.880466      20580

# %%
# 3. Save your joined csv as `joined.csv` into the data folder. 
joined_df.to_csv('joined.csv', index=False)

# %%
# 4. Load your newly saved file, see if it looks the same.  If not, try saving with argument `index=False`
# Looks the same

# %% [markdown]
# # Extra Credit
# Every question below this cell is extra credit and optional.

# %% [markdown]
# ### 1. (Easy) Explore this new PandasAI Package and tell me what its all about because I've never used it.
# * https://www.youtube.com/watch?v=5w6eZaoDVVk&ab_channel=CodingIsFun
# * See if you can use it on the listings.csv to find out some cool info. or answer some of the questions above.

# %% [markdown]
# ### 2. (Very Easy) Find other cool Panda packages / add ons and show us what they can do well. And how you installed them.

# %% [markdown]
# ### 3. (Medium) Use the grammys.csv data for the next section of questions.
#
# 1. Who was won Album of the Year in 2016?
#
#
# 2. Who won Best Rap Album in 2009?
#
#
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

# %% [markdown]
# ### (Hard) Load the Game Logs for 2022 and add the column names using a dictionary.
# * [Link to the data page](https://www.retrosheet.org/gamelogs/)
# * [Link to the column names](https://procatinator.com/)
# * haha, gotta find them yourself!

# %% [markdown]
# ### (Extra Hard) Download the files for the past 5 years into a new folder and add them all into one data frame using pandas, then save that new file.
# * Try to not hard code in the file names. We want to do this programmatically because what if we want to add new/more file names in the future.
